# %% [markdown]
# #Install the required dependencies for the model

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install jiwer
# !pip install datasets==1.18.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-_8dwxmm0
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-_8dwxmm0
#   Resolved https://github.com/openai/whisper.git to commit 5c1a8c10e762bf9c29fcf6b3e40f17bc8ab09864
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from openai-whisper==20230124) (1.21.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from openai-whisper==20230124) (1.13.1+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai-whisper==20230124) (4.64.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from openai-whisper==20230124) (9.0.0)
# Collecting transformers>=4.19.0
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 96.3 MB/s eta 0:00:00
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230124) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 90.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->openai-whisper==20230124) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers>=4.19.0->openai-whisper==20230124) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230124) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230124) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230124) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230124) (1.24.3)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (setup.py) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179333 sha256=b1b0b2b413f33e7418f0e52e4eb8456767ea966832ad7ce96c3a9ef8d492b023
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8r8rkztr/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# Successfully built openai-whisper
# Installing collected packages: tokenizers, ffmpeg-python, huggingface-hub, transformers, openai-whisper
# Successfully installed ffmpeg-python-0.2.0 huggingface-hub-0.12.0 openai-whisper-20230124 tokenizers-0.13.2 transformers-4.26.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.9 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein, jiwer
# Successfully installed jiwer-2.5.1 levenshtein-0.20.2 rapidfuzz-2.13.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets==1.18.3
#   Downloading datasets-1.18.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 KB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (4.64.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (3.8.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (0.3.6)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (21.3)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (1.21.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (2.25.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (2022.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets==1.18.3) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (4.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets==1.18.3) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets==1.18.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.18.3) (1.15.0)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-1.18.3 multiprocess-0.70.14 xxhash-3.2.0

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytube
#   Downloading pytube-12.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 7.4 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-12.1.2

# %% [markdown]
# ### Import the dependencies

# %%
import whisper
from pytube import YouTube
from glob import glob
import os
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# ### Load the timit dataset

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Downloading:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading and preparing dataset timit_asr/clean (download: 828.75 MiB, generated: 7.90 MiB, post-processed: Unknown size, total: 836.65 MiB) to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad...
# Downloading:   0%|          | 0.00/869M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset timit_asr downloaded and prepared to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Word error rate on timit dataset using different sizes of Whisper Model

# %% [markdown]
# * Note that since the requirement is to filter english data against non-english we have opted to select multilingual models rather than going for the model which is used only for english. Here we all are aware that timit dataset is purely English dataset still keeping this
# 8requirement in mind ,we will make use of the same procedure ie first language detection and later recognition

# %% [markdown]
# * Also, I have considered the train split in timit dataset to check word error rate on a larger collection of audio signals.

# %% [markdown]
# ### Tiny model (1GB)(39 Million learning parameters and 32x speed)
#
# ```
# # This is formatted as code
# ```

# %%
model = whisper.load_model('tiny')
# Out:
# 100%|██████████████████████████████████████| 72.1M/72.1M [00:00<00:00, 120MiB/s]

# %%
timit['train']['text'][0]
# Out:
# 'Would such an act of refusal be useful?'

# %%
def lan_detector(audio_file):
  print('reading the audio file')
  audio = whisper.load_audio(audio_file)
  audio = whisper.pad_or_trim(audio)
  mel = whisper.log_mel_spectrogram(audio).to(model.device)
  _, probs = model.detect_language(mel)
  if max(probs, key=probs.get) == 'en':
    return True
  return False

# %%
def speech2text(audio_file):
  text = model.transcribe(audio_file)
  return text["text"]

# %%
speech2text(timit['train']['file'][0])
# Out:
# ' with such an active refusal be useful.'

# %%
extracted_text = []
for i in tqdm(timit['train']['file']):
  #if lan_detector(i) == True:
    extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %%
len(extracted_text)
# Out:
# 4620

# %%
len(timit['train']['text'])
# Out:
# 4620

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['train']['text']})

# %%
data
# Out:
#                                              hypothesis  \
# 0                with such an active refusal be useful.
# 1         Don't ask me to carry an early rag like that.
# 2      Better Scotch Fudge goes well with vanilla ic...
# 3      She had your dark suit and greasy washwater a...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy washwater a...
# 4616   The water contained too much chlorine and stu...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus pine trees and redwoods on his walkthroug...
#
#                                               reference
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 2 columns]

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0                with such an active refusal be useful.
# 1         Don't ask me to carry an early rag like that.
# 2      Better Scotch Fudge goes well with vanilla ic...
# 3      She had your dark suit and greasy washwater a...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy washwater a...
# 4616   The water contained too much chlorine and stu...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus pine trees and redwoods on his walkthroug...
#
#                                               reference  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
#                                        hypothesis_clean  \
# 0                 with such an active refusal be useful
# 1         do not ask me to carry an early rag like that
# 2     better scotch fudge goes well with vanilla ice...
# 3     she had your dark suit and greasy washwater al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit and greasy washwater al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus pine trees and redwoods on his walkthrough...
#
#                                         reference_clean
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an oily rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit in greasy wash water al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit in greasy wash water al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 12.42 %

# %%
extracted_text = []
for i in tqdm(timit['test']['file']):
  extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['test']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0      The bungalow was pleasantly situated near the...
# 1      Don't ask me to carry in a really rag like that.
# 2                       Are you looking for employment?
# 3      She had your dark suit and greasy washwater a...
# 4       At Twilight on the 12th day we'll have Shibley.
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678     A low in them, silverware can often be flimsy.
# 1679   She slipped and sprayed her ankle on the stee...
#
#                                               reference  \
# 0     The bungalow was pleasantly situated near the ...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3     She had your dark suit in greasy wash water al...
# 4     At twilight on the twelfth day we'll have Chab...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679  She slipped and sprained her ankle on the stee...
#
#                                        hypothesis_clean  \
# 0     the bungalow was pleasantly situated near the ...
# 1      do not ask me to carry in a really rag like that
# 2                        are you looking for employment
# 3     she had your dark suit and greasy washwater al...
# 4      at twilight on the 12th day we will have shibley
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678       a low in them silverware can often be flimsy
# 1679  she slipped and sprayed her ankle on the steep...
#
#                                         reference_clean
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit in greasy wash water al...
# 4      at twilight on the 12th day we will have chablis
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
# [1680 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 10.85 %

# %% [markdown]
# ### BASE MODEL

# %% [markdown]
# Load the model

# %%
model = whisper.load_model('base')
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 51.9MiB/s]

# %%
extracted_text = []
for i in tqdm(timit['train']['file']):
  #if lan_detector(i) == True:
    extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['train']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0                with such an active refusal be useful.
# 1           Don't ask me to carry an Oli rag like that.
# 2      better scotch fudge goes well with vanilla ic...
# 3      She had your dark suit and greasy washwater a...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy washwater a...
# 4616   The water contained too much chlorine and stu...
# 4617                 movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus pine trees and redwoods on his walk throu...
#
#                                               reference  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
#                                        hypothesis_clean  \
# 0                 with such an active refusal be useful
# 1           do not ask me to carry an oli rag like that
# 2     better scotch fudge goes well with vanilla ice...
# 3     she had your dark suit and greasy washwater al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit and greasy washwater al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus pine trees and redwoods on his walk throug...
#
#                                         reference_clean
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an oily rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit in greasy wash water al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit in greasy wash water al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 8.67 %

# %%
extracted_text = []
for i in tqdm(timit['test']['file']):
  extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['test']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0      The bungalow was pleasantly situated near the...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3      She had your dark suit and greasy washwater a...
# 4      At twilight on the twelfth day we'll have Shi...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676      He rubbed his eye sleepily with one huge paw.
# 1677         Eight fuel guns were captured in position.
# 1678      Alone in him, Silverware can often be flimsy.
# 1679   She slipped and sprained her ankle on the ste...
#
#                                               reference  \
# 0     The bungalow was pleasantly situated near the ...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3     She had your dark suit in greasy wash water al...
# 4     At twilight on the twelfth day we'll have Chab...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679  She slipped and sprained her ankle on the stee...
#
#                                        hypothesis_clean  \
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit and greasy washwater al...
# 4       at twilight on the 12th day we will have shibli
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676       he rubbed his eye sleepily with one huge paw
# 1677              8 fuel guns were captured in position
# 1678        alone in him silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
#                                         reference_clean
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit in greasy wash water al...
# 4      at twilight on the 12th day we will have chablis
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
# [1680 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 7.59 %

# %% [markdown]
# ### Small model

# %%
model = whisper.load_model('small')
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:26<00:00, 18.6MiB/s]

# %%
extracted_text = []
for i in tqdm(timit['train']['file']):
  #if lan_detector(i) == True:
    extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['train']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an Olly rag like that.
# 2      Butterscotch fudge goes well with vanilla ice...
# 3      She had your dark suit and greasy wash water ...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy wash water ...
# 4616   The water contained too much chlorine and stu...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus saw pine trees and redwoods on his walk t...
#
#                                               reference  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
#                                        hypothesis_clean  \
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an olly rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit and greasy wash water a...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit and greasy wash water a...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
#                                         reference_clean
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an oily rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit in greasy wash water al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit in greasy wash water al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 4.67 %

# %%
extracted_text = []
for i in tqdm(timit['test']['file']):
  extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['test']['text']})

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0      The bungalow was pleasantly situated near the...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3      She had your dark suit and greasy wash water ...
# 4      At twilight on the twelfth day, we'll have Sh...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677         Eight fuel guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679   She slipped and sprained her ankle on the ste...
#
#                                               reference  \
# 0     The bungalow was pleasantly situated near the ...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3     She had your dark suit in greasy wash water al...
# 4     At twilight on the twelfth day we'll have Chab...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679  She slipped and sprained her ankle on the stee...
#
#                                        hypothesis_clean  \
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit and greasy wash water a...
# 4      at twilight on the 12th day we will have shiblee
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677              8 fuel guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
#                                         reference_clean
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit in greasy wash water al...
# 4      at twilight on the 12th day we will have chablis
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
# [1680 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 3.74 %

# %% [markdown]
# ### Medium model

# %%
model = whisper.load_model('medium')
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:05<00:00, 263MiB/s]

# %%
extracted_text = []
for i in tqdm(timit['train']['file']):
  #if lan_detector(i) == True:
    extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['train']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an Olli rag like that.
# 2      Butterscotch fudge goes well with vanilla ice...
# 3      She had your dark suit and greasy wash water ...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy wash water ...
# 4616   The water contained too much chlorine and stu...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus saw pine trees and redwoods on his walk t...
#
#                                               reference  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
#                                        hypothesis_clean  \
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an olli rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit and greasy wash water a...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit and greasy wash water a...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
#                                         reference_clean
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an oily rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit in greasy wash water al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit in greasy wash water al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 3.74 %

# %%
extracted_text = []
for i in tqdm(timit['test']['file']):
  extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['test']['text']})

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0      the bungalow was pleasantly situated near the...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3      She had your dark suit and greasy wash water ...
# 4      At twilight on the twelfth day we'll have Shi...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677         Eight fuel guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679   she slipped and sprained her ankle on the ste...
#
#                                               reference  \
# 0     The bungalow was pleasantly situated near the ...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3     She had your dark suit in greasy wash water al...
# 4     At twilight on the twelfth day we'll have Chab...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679  She slipped and sprained her ankle on the stee...
#
#                                        hypothesis_clean  \
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit and greasy wash water a...
# 4       at twilight on the 12th day we will have shibli
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677              8 fuel guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
#                                         reference_clean
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit in greasy wash water al...
# 4      at twilight on the 12th day we will have chablis
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
# [1680 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 3.06 %

# %% [markdown]
# ### Large

# %%
model = whisper.load_model('large')
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:29<00:00, 106MiB/s]

# %%
extracted_text = []
for i in tqdm(timit['train']['file']):
  if lan_detector(i) == True:
    extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['train']['text']})

# %%
import jiwer
from whisper.normalizers import EnglishTextNormalizer

normalizer = EnglishTextNormalizer()

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0               Would such an act of refusal be useful?
# 1           Don't ask me to carry an Oli rag like that.
# 2      Butterscotch fudge goes well with vanilla ice...
# 3      She had your dark suit and greasy wash water ...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615   She had your dark suit and greasy wash water ...
# 4616   The water contained too much chlorine and stu...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619   Gus saw pine trees and redwoods on his walk t...
#
#                                               reference  \
# 0               Would such an act of refusal be useful?
# 1          Don't ask me to carry an oily rag like that.
# 2     Butterscotch fudge goes well with vanilla ice ...
# 3     She had your dark suit in greasy wash water al...
# 4                                       I honor my mom.
# ...                                                 ...
# 4615  She had your dark suit in greasy wash water al...
# 4616  The water contained too much chlorine and stun...
# 4617                 Movies never have enough villains.
# 4618                    Does Hindu ideology honor cows?
# 4619  Gus saw pine trees and redwoods on his walk th...
#
#                                        hypothesis_clean  \
# 0                would such an act of refusal be useful
# 1           do not ask me to carry an oli rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit and greasy wash water a...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit and greasy wash water a...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
#                                         reference_clean
# 0                would such an act of refusal be useful
# 1          do not ask me to carry an oily rag like that
# 2     butterscotch fudge goes well with vanilla ice ...
# 3     she had your dark suit in greasy wash water al...
# 4                                        i honor my mom
# ...                                                 ...
# 4615  she had your dark suit in greasy wash water al...
# 4616  the water contained too much chlorine and stun...
# 4617                  movies never have enough villains
# 4618                     does hindu ideology honor cows
# 4619  gus saw pine trees and redwoods on his walk th...
#
# [4620 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 3.06 %

# %%
extracted_text = []
for i in tqdm(timit['test']['file']):
  extracted_text.append(speech2text(i))
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
data = pd.DataFrame.from_dict({"hypothesis":extracted_text,"reference":timit['test']['text']})

# %%
data["hypothesis_clean"] = [normalizer(text) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(text) for text in data["reference"]]
data
# Out:
#                                              hypothesis  \
# 0      The bungalow was pleasantly situated near the...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3      She had your dark suit and greasy wash water ...
# 4      At twilight on the 12th day, we'll have shibley.
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679   She slipped and sprained her ankle on the ste...
#
#                                               reference  \
# 0     The bungalow was pleasantly situated near the ...
# 1          Don't ask me to carry an oily rag like that.
# 2                       Are you looking for employment?
# 3     She had your dark suit in greasy wash water al...
# 4     At twilight on the twelfth day we'll have Chab...
# ...                                                 ...
# 1675            Pam gives driving lessons on Thursdays.
# 1676     He rubbed his eyes sleepily with one huge paw.
# 1677        Eight field guns were captured in position.
# 1678           Aluminum silverware can often be flimsy.
# 1679  She slipped and sprained her ankle on the stee...
#
#                                        hypothesis_clean  \
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit and greasy wash water a...
# 4      at twilight on the 12th day we will have shibley
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
#                                         reference_clean
# 0     the bungalow was pleasantly situated near the ...
# 1          do not ask me to carry an oily rag like that
# 2                        are you looking for employment
# 3     she had your dark suit in greasy wash water al...
# 4      at twilight on the 12th day we will have chablis
# ...                                                 ...
# 1675             pam gives driving lessons on thursdays
# 1676      he rubbed his eyes sleepily with one huge paw
# 1677             8 field guns were captured in position
# 1678            aluminum silverware can often be flimsy
# 1679  she slipped and sprained her ankle on the stee...
#
# [1680 rows x 4 columns]

# %%
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER: {wer * 100:.2f} %")
# Out:
# WER: 2.50 %

# %% [markdown]
# ### Transcribing youtube link using Whisper Model

# %% [markdown]
# ### Step1 : Extract audio from the youtube link

# %%
def youtube_audio(link):
    youtube_1 = YouTube(link)
    videos = youtube_1.streams.filter(only_audio=True)

    name = str(link.split('=')[-1])
    out_file = videos[0].download(name)
    
    link = name.split('=')[-1]
    new_filename = link+".wav"
    print(new_filename)
    os.rename(out_file, new_filename)
    print(name)
    return new_filename,link

# %%
youtube_audio('https://www.youtube.com/watch?v=PZ7lDrwYdZc')
# Out:
# PZ7lDrwYdZc.wav
# PZ7lDrwYdZc
# ('PZ7lDrwYdZc.wav', 'PZ7lDrwYdZc')

# %%
path="/content/PZ7lDrwYdZc.wav"

# %%
extracted_text = []
if lan_detector(path) == True:
    extracted_text.append(speech2text('/content/PZ7lDrwYdZc.wav'))
# Out:
# reading the audio file

# %%
extracted_text
# Out:
# [" Do you ever feel like you're just floating through life, but not actually getting closer to the person that you want to be? It usually happens around New Years. You imagine all the bad habits you're going to break free from, and all the good habits you will begin. This time it will be different you say to yourself. This time I am going to do the things that I say I will, only to end up back where you began shortly after, and no closer to what you had envisaged. So the question is, how do you break free from bad habits and make the habits you desire easier and automatic? Atomic Habits by James Clear answers all these questions. We're going to be doing a fast paced, detailed summary of the book, and dive deep into topics like habit loops, dopamine spikes, priming your environment, plus heaps more. And make sure you stick around until the end of the video where I go through step by step how I'm personally using this book to improve my own habits. I hope this summary inspires you to go out and grab a copy of the book for yourself, because this book deserves a space on everyone's bookshelf. Let's jump into it. Imagine a plane taking off and traveling from New York to Los Angeles. Just before takeoff you adjust the plane just slightly by 3 degrees or around 80 inches. If you were to keep flying in a straight line, you would end up closer to Tijuana in Mexico than in your intended destination of Los Angeles. And the same goes for our habits. Tiny changes in our habits can change the trajectory of our lives in ways that we can't even notice until many years into the future looking back. In both good ways and bad, you are your habits. The power of atomic habits. A slight change in your daily habits can guide your life to a very different destination. Massive Action vs 1% Improvements Far too often we convince ourselves that massive success is only possible through massive action in any goal we are pursuing. We expect ourselves to make some quantum leap or momentous improvement that will gain others' attention. However, it is the tiny improvements that aren't even noticeable at first that create incredible change. Let's look deeper into the math. 1% better every day for a year will compound to 37 times better, but 1% worse every day over a year will bring you close to zero. Your habits can compound against you in the form of things like stress or negative self-talk, or they can compound for you in the form of things like knowledge, productivity, skills, and relationships. Success is the product of daily habits, not once-in-a-lifetime transformations. The Truth About Progress When you start any endeavor in your life, here is what you think should happen. Linear progress. But here is what actually happens. Notice this section here in the beginning. Small changes in our progress are not even noticeable. James Clear refers to this part of the graph as the valley of disappointment. You've done so much, you've put in so much effort, and you can barely see any results. This is where most people fail and slip back into their old routines. The most powerful outcomes of any compounding process are delayed, so patience is required. Goals vs. Systems Forget about goals, focus on systems instead. A goal is the result you want to accomplish. Systems deal with processes that lead to the results. The conventional wisdom suggests that the best way to achieve anything we want in life, be it getting into better shape, building a successful business, or spending more time with family, is to set specific, realistic goals. But if you completely ignored your goals and focused only on your systems, would you still succeed? The author of this book argues that you would. Here are some problems with only having goals. Successful and unsuccessful people share the same goals, so therefore the goal cannot be what differentiates winners from losers. Achieving a goal only changes your life for that moment in time. Goals can create an either-or conflict. Either you  ...
